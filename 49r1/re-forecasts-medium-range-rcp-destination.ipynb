# %% [markdown]
# # Medium range from the RCP destination

# %% [markdown]
# This notebook will show you:
# - how to find which dates and steps to use to download the re-forecacsts - 6-hourly steps from medium range re-forecasts
# - download the re-forecasts
# - calculate daily mean/max/min/sum of the parameter
# - calculate the percentiles, mean and standard deviation of the fields for each day
# - calculate the percentiles for each day
#
# Please note that the climate built using this notebook is only valid for the date it was built. If you want to build the climate on some other day, you need to download the data again with the correct dates and steps.
#
# If you want to build the climate every day, you may download all the available steps at once and reuse the files.

# %% [markdown]
# For this notebook to work, we will need the libraries from the next cell.
#
# TO DO: add the list here and put the links to the documentation

# %%
import datetime
from earthkit.time import Sequence, model_climate_dates, date_range, DailySequence
import requests
import metview as mv
import os

# %% [markdown]
# Sequenece is Abstract representation of a sequence of dates.
# For the re-forecasts we use either 'ecmwf-4days' (medium) or ecmwf-2days (sub-seasonal) sequence. These are built in, and represent configuration of ECMWF forecast systems.

# %%
sequence = Sequence.from_resource("ecmwf-4days")
sequence
# Out:
# MonthlySequence(days=[1, 5, 9, 13, 17, 21, 25, 29], excludes={(2, 29)})

# %% [markdown]
# Next thing we need is to know what dates we need to build the model climate for today's forecast.
# Form medium range model climate (M climate) we can get this using the model_climate_dates function.

# %% [markdown]
# model_climate_dates(reference: date, start: date | int, end: date | int, before: timedelta | int, after: timedelta | int, sequence: Sequence)→ Iterator[date]
# Parameters:
# - `reference (datetime.date)` – Reference date for the climate
# - `start (datetime.date or int)` – Start of the climatological period. Either a full date or a year
# - `end (datetime.date or int)` – End of the climatological period. Either a full date or a year
# - `before (datetime.timedelta or int)` – Cut-off before the reference date. Either a timedelta or a number of days
# - `after (datetime.timedelta or int)` – Cut-off after the reference date. Either a timedelta or a number of days
# - `sequence (earthkit.time.sequence.Sequence)` – Sequence of available dates in the reference set
#
# Returns: Sequence of dates

# %% [markdown]
# Now we have a sequence, we can find a closest reforecast date for today, and from there, all the reforecast dates we need to calculate the model climate.

# %%
today = datetime.date.today()
today
# Out:
# datetime.date(2024, 9, 11)

# %% [markdown]
# Now we need to calculate the closest day of the ECMWF re-forecasts.
# We will use the **nearest** funciton.

# %%
clim_date = sequence.nearest(today)
clim_date
# Out:
# datetime.date(2024, 9, 9)

# %% [markdown]
# Next we will calculate the sequence of 9 dates, around our climatology date (including the climatology date).
# For this we can use the bracket function.
# We need to give it `clim_date`, number of days around `clim_date` we want reforecasts for and we need to set `strict` to False to include the `clim_date` in the set of dates.

# %%
clim_dates = sequence.bracket(clim_date,4,strict=False)
clim_dates
# Out:
# <generator object Sequence.bracket at 0x1113c9ad0>

# %% [markdown]
# We can loop through the `clim_dates` to see what we got:

# %%
for c in clim_dates:
    print(c)
# Out:
# 2024-08-25
# 2024-08-29
# 2024-09-01
# 2024-09-05
# 2024-09-09
# 2024-09-13
# 2024-09-17
# 2024-09-21
# 2024-09-25

# %% [markdown]
# We have prepared a test set of reforecasts available at the address: https://xdiss.ecmwf.int/ecpds/home/rcp/
# From here users can download medium and sub-seasonal range re-forecasts to test their system.
# **The data here is available strictly for testing and the operational and commercial use is not allowed.**
#
# Before 11 September we were uploading all available parameters to this system, however this proved to be challenging for users due to volume of the data. Therefore, since 13 September we have reduced the number of available parameters to those that we produce the M-climate for.

# %%
clim_dates = sequence.bracket(clim_date,4,strict=False)
for date in clim_dates:
    month, day = date.month, date.day
    print(month,day)
    ref_date = date.strftime("%Y%m%d")
    month_day_str = date.strftime("%m%d")
    forecast_seq = DailySequence()
    fdate = date
    for i in range(7):        
        month_day_str_f = fdate.strftime("%m%d")
        url = f'https://xdiss.ecmwf.int/ecpds/home/rcp/{ref_date}/mediumrange/A1I{month_day_str}0000{month_day_str_f}____0079.RCP91DG1000001' 
        print(url)
        local_filename = f"A1I{month_day_str}0000{month_day_str_f}____0079.RCP91DG1000001"
        t2m_filename = f't2m_{local_filename}.grib'
        
        if os.path.exists(local_filename) or os.path.exists(t2m_filename):
            pass
        else:
            # Make the request to download the file
            response = requests.get(url)
            
            # Check if the request was successful
            if response.status_code == 200:
                # Write the content to the local file
                with open(local_filename, 'wb') as f:
                    f.write(response.content)
                print(f"File downloaded successfully and saved as {local_filename}")
            else:
                print(f"Failed to download file. Status code: {response.status_code}")


        if os.path.exists(t2m_filename):
            print(f"File {t2m_filename} is already there.")
        else:
            data = mv.Fieldset(path=local_filename)
        
            t2m = data.select(shortName='2t')
            
            t2m.write(t2m_filename)
            print(f"Saved {t2m_filename}")
    
            if os.path.exists(local_filename):
              os.remove(local_filename)
            else:
              print("The file does not exist")
            
        fdate = forecast_seq.next(fdate)
# Out:
# 8 25
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240825/mediumrange/A1I082500000825____0079.RCP91DG1000001
# File t2m_A1I082500000825____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240825/mediumrange/A1I082500000826____0079.RCP91DG1000001
# File t2m_A1I082500000826____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240825/mediumrange/A1I082500000827____0079.RCP91DG1000001
# File t2m_A1I082500000827____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240825/mediumrange/A1I082500000828____0079.RCP91DG1000001
# File t2m_A1I082500000828____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240825/mediumrange/A1I082500000829____0079.RCP91DG1000001
# File t2m_A1I082500000829____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240825/mediumrange/A1I082500000830____0079.RCP91DG1000001
# File t2m_A1I082500000830____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240825/mediumrange/A1I082500000831____0079.RCP91DG1000001
# File t2m_A1I082500000831____0079.RCP91DG1000001.grib is already there.
# 8 29
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240829/mediumrange/A1I082900000829____0079.RCP91DG1000001
# File t2m_A1I082900000829____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240829/mediumrange/A1I082900000830____0079.RCP91DG1000001
# File t2m_A1I082900000830____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240829/mediumrange/A1I082900000831____0079.RCP91DG1000001
# File t2m_A1I082900000831____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240829/mediumrange/A1I082900000901____0079.RCP91DG1000001
# File t2m_A1I082900000901____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240829/mediumrange/A1I082900000902____0079.RCP91DG1000001
# File t2m_A1I082900000902____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240829/mediumrange/A1I082900000903____0079.RCP91DG1000001
# File t2m_A1I082900000903____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240829/mediumrange/A1I082900000904____0079.RCP91DG1000001
# File t2m_A1I082900000904____0079.RCP91DG1000001.grib is already there.
# 9 1
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240901/mediumrange/A1I090100000901____0079.RCP91DG1000001
# File t2m_A1I090100000901____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240901/mediumrange/A1I090100000902____0079.RCP91DG1000001
# File t2m_A1I090100000902____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240901/mediumrange/A1I090100000903____0079.RCP91DG1000001
# File t2m_A1I090100000903____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240901/mediumrange/A1I090100000904____0079.RCP91DG1000001
# File t2m_A1I090100000904____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240901/mediumrange/A1I090100000905____0079.RCP91DG1000001
# File t2m_A1I090100000905____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240901/mediumrange/A1I090100000906____0079.RCP91DG1000001
# File t2m_A1I090100000906____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240901/mediumrange/A1I090100000907____0079.RCP91DG1000001
# File t2m_A1I090100000907____0079.RCP91DG1000001.grib is already there.
# 9 5
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240905/mediumrange/A1I090500000905____0079.RCP91DG1000001
# File t2m_A1I090500000905____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240905/mediumrange/A1I090500000906____0079.RCP91DG1000001
# File t2m_A1I090500000906____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240905/mediumrange/A1I090500000907____0079.RCP91DG1000001
# File t2m_A1I090500000907____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240905/mediumrange/A1I090500000908____0079.RCP91DG1000001
# File t2m_A1I090500000908____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240905/mediumrange/A1I090500000909____0079.RCP91DG1000001
# File t2m_A1I090500000909____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240905/mediumrange/A1I090500000910____0079.RCP91DG1000001
# File t2m_A1I090500000910____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240905/mediumrange/A1I090500000911____0079.RCP91DG1000001
# File t2m_A1I090500000911____0079.RCP91DG1000001.grib is already there.
# 9 9
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240909/mediumrange/A1I090900000909____0079.RCP91DG1000001
# File t2m_A1I090900000909____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240909/mediumrange/A1I090900000910____0079.RCP91DG1000001
# File t2m_A1I090900000910____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240909/mediumrange/A1I090900000911____0079.RCP91DG1000001
# File t2m_A1I090900000911____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240909/mediumrange/A1I090900000912____0079.RCP91DG1000001
# File t2m_A1I090900000912____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240909/mediumrange/A1I090900000913____0079.RCP91DG1000001
# File t2m_A1I090900000913____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240909/mediumrange/A1I090900000914____0079.RCP91DG1000001
# File t2m_A1I090900000914____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240909/mediumrange/A1I090900000915____0079.RCP91DG1000001
# File t2m_A1I090900000915____0079.RCP91DG1000001.grib is already there.
# 9 13
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240913/mediumrange/A1I091300000913____0079.RCP91DG1000001
# File t2m_A1I091300000913____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240913/mediumrange/A1I091300000914____0079.RCP91DG1000001
# File t2m_A1I091300000914____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240913/mediumrange/A1I091300000915____0079.RCP91DG1000001
# File t2m_A1I091300000915____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240913/mediumrange/A1I091300000916____0079.RCP91DG1000001
# File t2m_A1I091300000916____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240913/mediumrange/A1I091300000917____0079.RCP91DG1000001
# File t2m_A1I091300000917____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240913/mediumrange/A1I091300000918____0079.RCP91DG1000001
# File t2m_A1I091300000918____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240913/mediumrange/A1I091300000919____0079.RCP91DG1000001
# File t2m_A1I091300000919____0079.RCP91DG1000001.grib is already there.
# 9 17
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240917/mediumrange/A1I091700000917____0079.RCP91DG1000001
# File t2m_A1I091700000917____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240917/mediumrange/A1I091700000918____0079.RCP91DG1000001
# File t2m_A1I091700000918____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240917/mediumrange/A1I091700000919____0079.RCP91DG1000001
# File t2m_A1I091700000919____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240917/mediumrange/A1I091700000920____0079.RCP91DG1000001
# File t2m_A1I091700000920____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240917/mediumrange/A1I091700000921____0079.RCP91DG1000001
# File t2m_A1I091700000921____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240917/mediumrange/A1I091700000922____0079.RCP91DG1000001
# File t2m_A1I091700000922____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240917/mediumrange/A1I091700000923____0079.RCP91DG1000001
# File t2m_A1I091700000923____0079.RCP91DG1000001.grib is already there.
# 9 21
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240921/mediumrange/A1I092100000921____0079.RCP91DG1000001
# File t2m_A1I092100000921____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240921/mediumrange/A1I092100000922____0079.RCP91DG1000001
# File t2m_A1I092100000922____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240921/mediumrange/A1I092100000923____0079.RCP91DG1000001
# File t2m_A1I092100000923____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240921/mediumrange/A1I092100000924____0079.RCP91DG1000001
# File t2m_A1I092100000924____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240921/mediumrange/A1I092100000925____0079.RCP91DG1000001
# File t2m_A1I092100000925____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240921/mediumrange/A1I092100000926____0079.RCP91DG1000001
# File t2m_A1I092100000926____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240921/mediumrange/A1I092100000927____0079.RCP91DG1000001
# File t2m_A1I092100000927____0079.RCP91DG1000001.grib is already there.
# 9 25
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240925/mediumrange/A1I092500000925____0079.RCP91DG1000001
# File t2m_A1I092500000925____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240925/mediumrange/A1I092500000926____0079.RCP91DG1000001
# File t2m_A1I092500000926____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240925/mediumrange/A1I092500000927____0079.RCP91DG1000001
# File t2m_A1I092500000927____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240925/mediumrange/A1I092500000928____0079.RCP91DG1000001
# File t2m_A1I092500000928____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240925/mediumrange/A1I092500000929____0079.RCP91DG1000001
# File t2m_A1I092500000929____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240925/mediumrange/A1I092500000930____0079.RCP91DG1000001
# File t2m_A1I092500000930____0079.RCP91DG1000001.grib is already there.
# https://xdiss.ecmwf.int/ecpds/home/rcp/20240925/mediumrange/A1I092500001001____0079.RCP91DG1000001
# File t2m_A1I092500001001____0079.RCP91DG1000001.grib is already there.

# %% [markdown]
# Each file contains 6 steps for that day: 0, 6, 12 and 18.
# Let's open one file (the last created) to see what we have inside

# %%
data = mv.Fieldset(path=t2m_filename)
data.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>2t</th><td style='text-align: left;'>surface</td><td style='text-align: left;'>0</td><td style='text-align: left;'>20240925</td><td style='text-align: left;'>0</td><td style='text-align: left;'>144,150,...</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>167</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfh</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0079</td></tr>
#                 </table>

# %% [markdown]
# We can also list all the fields

# %%
data.ls()
# Out:
#         centre shortName typeOfLevel  level  dataDate  dataTime stepRange  \
# Message
# 0        ecmf      2t       surface     0    20110925      0        162
# 1        ecmf      2t       surface     0    20110925      0        162
# 2        ecmf      2t       surface     0    20190925      0        162
# 3        ecmf      2t       surface     0    20110925      0        144
# 4        ecmf      2t       surface     0    20110925      0        162
# ...        ...       ...         ...    ...       ...       ...       ...
# 875      ecmf      2t       surface     0    20230925      0        156
# 876      ecmf      2t       surface     0    20220925      0        156
# 877      ecmf      2t       surface     0    20040925      0        144
# 878      ecmf      2t       surface     0    20040925      0        150
# 879      ecmf      2t       surface     0    20040925      0        156
#
#         dataType number   gridType
# Message
# 0          pf       5    regular_ll
# 1          pf       6    regular_ll
# 2          pf       3    regular_ll
# 3          pf       1    regular_ll
# 4          pf       8    regular_ll
# ...          ...    ...         ...
# 875        pf      10    regular_ll
# 876        pf       6    regular_ll
# 877        pf       2    regular_ll
# 878        pf       2    regular_ll
# 879        pf       2    regular_ll
#
# [880 rows x 10 columns]

# %% [markdown]
# Next thing we will do is calculate daily mean only over steps.

# %%
daily_mean = data.mean(dim=["step"],
    preserve_dims=["shortName", "level", "number", "dataDate"])

# %%
daily_mean.ls()
# Out:
#         centre shortName typeOfLevel  level  dataDate  dataTime stepRange  \
# Message
# 0        ecmf      2t       surface     0    20110925      0        162
# 1        ecmf      2t       surface     0    20190925      0        162
# 2        ecmf      2t       surface     0    20120925      0        162
# 3        ecmf      2t       surface     0    20090925      0        162
# 4        ecmf      2t       surface     0    20200925      0        162
# 5        ecmf      2t       surface     0    20100925      0        162
# 6        ecmf      2t       surface     0    20150925      0        162
# 7        ecmf      2t       surface     0    20170925      0        162
# 8        ecmf      2t       surface     0    20140925      0        162
# 9        ecmf      2t       surface     0    20160925      0        162
# 10       ecmf      2t       surface     0    20180925      0        162
# 11       ecmf      2t       surface     0    20130925      0        162
# 12       ecmf      2t       surface     0    20220925      0        162
# 13       ecmf      2t       surface     0    20050925      0        162
# 14       ecmf      2t       surface     0    20070925      0        162
# 15       ecmf      2t       surface     0    20210925      0        162
# 16       ecmf      2t       surface     0    20040925      0        162
# 17       ecmf      2t       surface     0    20060925      0        162
# 18       ecmf      2t       surface     0    20080925      0        162
# 19       ecmf      2t       surface     0    20230925      0        162
# 20       ecmf      2t       surface     0    20110925      0        162
# 21       ecmf      2t       surface     0    20190925      0        162
# 22       ecmf      2t       surface     0    20120925      0        162
# 23       ecmf      2t       surface     0    20090925      0        162
# 24       ecmf      2t       surface     0    20200925      0        162
# 25       ecmf      2t       surface     0    20100925      0        162
# 26       ecmf      2t       surface     0    20150925      0        162
# 27       ecmf      2t       surface     0    20170925      0        162
# 28       ecmf      2t       surface     0    20140925      0        162
# 29       ecmf      2t       surface     0    20160925      0        162
# 30       ecmf      2t       surface     0    20180925      0        162
# 31       ecmf      2t       surface     0    20130925      0        162
# 32       ecmf      2t       surface     0    20220925      0        162
# 33       ecmf      2t       surface     0    20050925      0        162
# 34       ecmf      2t       surface     0    20070925      0        162
# 35       ecmf      2t       surface     0    20210925      0        162
# 36       ecmf      2t       surface     0    20040925      0        162
# 37       ecmf      2t       surface     0    20060925      0        162
# 38       ecmf      2t       surface     0    20080925      0        162
# 39       ecmf      2t       surface     0    20230925      0        162
# 40       ecmf      2t       surface     0    20110925      0        162
# 41       ecmf      2t       surface     0    20190925      0        162
# 42       ecmf      2t       surface     0    20120925      0        162
# 43       ecmf      2t       surface     0    20090925      0        162
# 44       ecmf      2t       surface     0    20200925      0        162
# 45       ecmf      2t       surface     0    20100925      0        162
# 46       ecmf      2t       surface     0    20150925      0        162
# 47       ecmf      2t       surface     0    20170925      0        162
# 48       ecmf      2t       surface     0    20140925      0        162
# 49       ecmf      2t       surface     0    20160925      0        162
# 50       ecmf      2t       surface     0    20180925      0        162
# 51       ecmf      2t       surface     0    20130925      0        162
# 52       ecmf      2t       surface     0    20220925      0        162
# 53       ecmf      2t       surface     0    20050925      0        162
# 54       ecmf      2t       surface     0    20070925      0        162
# 55       ecmf      2t       surface     0    20210925      0        162
# 56       ecmf      2t       surface     0    20040925      0        162
# 57       ecmf      2t       surface     0    20060925      0        162
# 58       ecmf      2t       surface     0    20080925      0        162
# 59       ecmf      2t       surface     0    20230925      0        162
# 60       ecmf      2t       surface     0    20110925      0        144
# 61       ecmf      2t       surface     0    20190925      0        144
# 62       ecmf      2t       surface     0    20120925      0        144
# 63       ecmf      2t       surface     0    20090925      0        144
# 64       ecmf      2t       surface     0    20200925      0        144
# 65       ecmf      2t       surface     0    20100925      0        144
# 66       ecmf      2t       surface     0    20150925      0        144
# 67       ecmf      2t       surface     0    20170925      0        144
# 68       ecmf      2t       surface     0    20140925      0        144
# 69       ecmf      2t       surface     0    20160925      0        144
# 70       ecmf      2t       surface     0    20180925      0        144
# 71       ecmf      2t       surface     0    20130925      0        144
# 72       ecmf      2t       surface     0    20220925      0        144
# 73       ecmf      2t       surface     0    20050925      0        144
# 74       ecmf      2t       surface     0    20070925      0        144
# 75       ecmf      2t       surface     0    20210925      0        144
# 76       ecmf      2t       surface     0    20040925      0        144
# 77       ecmf      2t       surface     0    20060925      0        144
# 78       ecmf      2t       surface     0    20080925      0        144
# 79       ecmf      2t       surface     0    20230925      0        144
# 80       ecmf      2t       surface     0    20110925      0        162
# 81       ecmf      2t       surface     0    20190925      0        162
# 82       ecmf      2t       surface     0    20120925      0        162
# 83       ecmf      2t       surface     0    20090925      0        162
# 84       ecmf      2t       surface     0    20200925      0        162
# 85       ecmf      2t       surface     0    20100925      0        162
# 86       ecmf      2t       surface     0    20150925      0        162
# 87       ecmf      2t       surface     0    20170925      0        162
# 88       ecmf      2t       surface     0    20140925      0        162
# 89       ecmf      2t       surface     0    20160925      0        162
# 90       ecmf      2t       surface     0    20180925      0        162
# 91       ecmf      2t       surface     0    20130925      0        162
# 92       ecmf      2t       surface     0    20220925      0        162
# 93       ecmf      2t       surface     0    20050925      0        162
# 94       ecmf      2t       surface     0    20070925      0        162
# 95       ecmf      2t       surface     0    20210925      0        162
# 96       ecmf      2t       surface     0    20040925      0        162
# 97       ecmf      2t       surface     0    20060925      0        162
# 98       ecmf      2t       surface     0    20080925      0        162
# 99       ecmf      2t       surface     0    20230925      0        162
# 100      ecmf      2t       surface     0    20110925      0        162
# 101      ecmf      2t       surface     0    20190925      0        162
# 102      ecmf      2t       surface     0    20120925      0        162
# 103      ecmf      2t       surface     0    20090925      0        162
# 104      ecmf      2t       surface     0    20200925      0        162
# 105      ecmf      2t       surface     0    20100925      0        162
# 106      ecmf      2t       surface     0    20150925      0        162
# 107      ecmf      2t       surface     0    20170925      0        162
# 108      ecmf      2t       surface     0    20140925      0        162
# 109      ecmf      2t       surface     0    20160925      0        162
# 110      ecmf      2t       surface     0    20180925      0        162
# 111      ecmf      2t       surface     0    20130925      0        162
# 112      ecmf      2t       surface     0    20220925      0        162
# 113      ecmf      2t       surface     0    20050925      0        162
# 114      ecmf      2t       surface     0    20070925      0        162
# 115      ecmf      2t       surface     0    20210925      0        162
# 116      ecmf      2t       surface     0    20040925      0        162
# 117      ecmf      2t       surface     0    20060925      0        162
# 118      ecmf      2t       surface     0    20080925      0        162
# 119      ecmf      2t       surface     0    20230925      0        162
# 120      ecmf      2t       surface     0    20110925      0        162
# 121      ecmf      2t       surface     0    20190925      0        162
# 122      ecmf      2t       surface     0    20120925      0        162
# 123      ecmf      2t       surface     0    20090925      0        162
# 124      ecmf      2t       surface     0    20200925      0        162
# 125      ecmf      2t       surface     0    20100925      0        162
# 126      ecmf      2t       surface     0    20150925      0        162
# 127      ecmf      2t       surface     0    20170925      0        162
# 128      ecmf      2t       surface     0    20140925      0        162
# 129      ecmf      2t       surface     0    20160925      0        162
# 130      ecmf      2t       surface     0    20180925      0        162
# 131      ecmf      2t       surface     0    20130925      0        162
# 132      ecmf      2t       surface     0    20220925      0        162
# 133      ecmf      2t       surface     0    20050925      0        162
# 134      ecmf      2t       surface     0    20070925      0        162
# 135      ecmf      2t       surface     0    20210925      0        162
# 136      ecmf      2t       surface     0    20040925      0        162
# 137      ecmf      2t       surface     0    20060925      0        162
# 138      ecmf      2t       surface     0    20080925      0        162
# 139      ecmf      2t       surface     0    20230925      0        162
# 140      ecmf      2t       surface     0    20110925      0        162
# 141      ecmf      2t       surface     0    20190925      0        162
# 142      ecmf      2t       surface     0    20120925      0        162
# 143      ecmf      2t       surface     0    20090925      0        162
# 144      ecmf      2t       surface     0    20200925      0        162
# 145      ecmf      2t       surface     0    20100925      0        162
# 146      ecmf      2t       surface     0    20150925      0        162
# 147      ecmf      2t       surface     0    20170925      0        162
# 148      ecmf      2t       surface     0    20140925      0        162
# 149      ecmf      2t       surface     0    20160925      0        162
# 150      ecmf      2t       surface     0    20180925      0        162
# 151      ecmf      2t       surface     0    20130925      0        162
# 152      ecmf      2t       surface     0    20220925      0        144
# 153      ecmf      2t       surface     0    20050925      0        162
# 154      ecmf      2t       surface     0    20070925      0        162
# 155      ecmf      2t       surface     0    20210925      0        162
# 156      ecmf      2t       surface     0    20040925      0        162
# 157      ecmf      2t       surface     0    20060925      0        162
# 158      ecmf      2t       surface     0    20080925      0        162
# 159      ecmf      2t       surface     0    20230925      0        162
# 160      ecmf      2t       surface     0    20110925      0        162
# 161      ecmf      2t       surface     0    20190925      0        162
# 162      ecmf      2t       surface     0    20120925      0        162
# 163      ecmf      2t       surface     0    20090925      0        162
# 164      ecmf      2t       surface     0    20200925      0        162
# 165      ecmf      2t       surface     0    20100925      0        162
# 166      ecmf      2t       surface     0    20150925      0        162
# 167      ecmf      2t       surface     0    20170925      0        162
# 168      ecmf      2t       surface     0    20140925      0        162
# 169      ecmf      2t       surface     0    20160925      0        162
# 170      ecmf      2t       surface     0    20180925      0        162
# 171      ecmf      2t       surface     0    20130925      0        162
# 172      ecmf      2t       surface     0    20220925      0        162
# 173      ecmf      2t       surface     0    20050925      0        162
# 174      ecmf      2t       surface     0    20070925      0        162
# 175      ecmf      2t       surface     0    20210925      0        162
# 176      ecmf      2t       surface     0    20040925      0        162
# 177      ecmf      2t       surface     0    20060925      0        162
# 178      ecmf      2t       surface     0    20080925      0        162
# 179      ecmf      2t       surface     0    20230925      0        162
# 180      ecmf      2t       surface     0    20110925      0        162
# 181      ecmf      2t       surface     0    20190925      0        162
# 182      ecmf      2t       surface     0    20120925      0        162
# 183      ecmf      2t       surface     0    20090925      0        162
# 184      ecmf      2t       surface     0    20200925      0        162
# 185      ecmf      2t       surface     0    20100925      0        162
# 186      ecmf      2t       surface     0    20150925      0        162
# 187      ecmf      2t       surface     0    20170925      0        162
# 188      ecmf      2t       surface     0    20140925      0        162
# 189      ecmf      2t       surface     0    20160925      0        162
# 190      ecmf      2t       surface     0    20180925      0        162
# 191      ecmf      2t       surface     0    20130925      0        162
# 192      ecmf      2t       surface     0    20220925      0        162
# 193      ecmf      2t       surface     0    20050925      0        162
# 194      ecmf      2t       surface     0    20070925      0        162
# 195      ecmf      2t       surface     0    20210925      0        162
# 196      ecmf      2t       surface     0    20040925      0        162
# 197      ecmf      2t       surface     0    20060925      0        162
# 198      ecmf      2t       surface     0    20080925      0        162
# 199      ecmf      2t       surface     0    20230925      0        162
# 200      ecmf      2t       surface     0    20110925      0        162
# 201      ecmf      2t       surface     0    20190925      0        162
# 202      ecmf      2t       surface     0    20120925      0        162
# 203      ecmf      2t       surface     0    20090925      0        162
# 204      ecmf      2t       surface     0    20200925      0        162
# 205      ecmf      2t       surface     0    20100925      0        162
# 206      ecmf      2t       surface     0    20150925      0        162
# 207      ecmf      2t       surface     0    20170925      0        162
# 208      ecmf      2t       surface     0    20140925      0        162
# 209      ecmf      2t       surface     0    20160925      0        162
# 210      ecmf      2t       surface     0    20180925      0        162
# 211      ecmf      2t       surface     0    20130925      0        162
# 212      ecmf      2t       surface     0    20220925      0        162
# 213      ecmf      2t       surface     0    20050925      0        162
# 214      ecmf      2t       surface     0    20070925      0        162
# 215      ecmf      2t       surface     0    20210925      0        162
# 216      ecmf      2t       surface     0    20040925      0        162
# 217      ecmf      2t       surface     0    20060925      0        162
# 218      ecmf      2t       surface     0    20080925      0        162
# 219      ecmf      2t       surface     0    20230925      0        162
#
#         dataType number   gridType
# Message
# 0          pf       5    regular_ll
# 1          pf       5    regular_ll
# 2          pf       5    regular_ll
# 3          pf       5    regular_ll
# 4          pf       5    regular_ll
# 5          pf       5    regular_ll
# 6          pf       5    regular_ll
# 7          pf       5    regular_ll
# 8          pf       5    regular_ll
# 9          pf       5    regular_ll
# 10         pf       5    regular_ll
# 11         pf       5    regular_ll
# 12         pf       5    regular_ll
# 13         pf       5    regular_ll
# 14         pf       5    regular_ll
# 15         pf       5    regular_ll
# 16         pf       5    regular_ll
# 17         pf       5    regular_ll
# 18         pf       5    regular_ll
# 19         pf       5    regular_ll
# 20         pf       6    regular_ll
# 21         pf       6    regular_ll
# 22         pf       6    regular_ll
# 23         pf       6    regular_ll
# 24         pf       6    regular_ll
# 25         pf       6    regular_ll
# 26         pf       6    regular_ll
# 27         pf       6    regular_ll
# 28         pf       6    regular_ll
# 29         pf       6    regular_ll
# 30         pf       6    regular_ll
# 31         pf       6    regular_ll
# 32         pf       6    regular_ll
# 33         pf       6    regular_ll
# 34         pf       6    regular_ll
# 35         pf       6    regular_ll
# 36         pf       6    regular_ll
# 37         pf       6    regular_ll
# 38         pf       6    regular_ll
# 39         pf       6    regular_ll
# 40         pf       3    regular_ll
# 41         pf       3    regular_ll
# 42         pf       3    regular_ll
# 43         pf       3    regular_ll
# 44         pf       3    regular_ll
# 45         pf       3    regular_ll
# 46         pf       3    regular_ll
# 47         pf       3    regular_ll
# 48         pf       3    regular_ll
# 49         pf       3    regular_ll
# 50         pf       3    regular_ll
# 51         pf       3    regular_ll
# 52         pf       3    regular_ll
# 53         pf       3    regular_ll
# 54         pf       3    regular_ll
# 55         pf       3    regular_ll
# 56         pf       3    regular_ll
# 57         pf       3    regular_ll
# 58         pf       3    regular_ll
# 59         pf       3    regular_ll
# 60         pf       1    regular_ll
# 61         pf       1    regular_ll
# 62         pf       1    regular_ll
# 63         pf       1    regular_ll
# 64         pf       1    regular_ll
# 65         pf       1    regular_ll
# 66         pf       1    regular_ll
# 67         pf       1    regular_ll
# 68         pf       1    regular_ll
# 69         pf       1    regular_ll
# 70         pf       1    regular_ll
# 71         pf       1    regular_ll
# 72         pf       1    regular_ll
# 73         pf       1    regular_ll
# 74         pf       1    regular_ll
# 75         pf       1    regular_ll
# 76         pf       1    regular_ll
# 77         pf       1    regular_ll
# 78         pf       1    regular_ll
# 79         pf       1    regular_ll
# 80         pf       8    regular_ll
# 81         pf       8    regular_ll
# 82         pf       8    regular_ll
# 83         pf       8    regular_ll
# 84         pf       8    regular_ll
# 85         pf       8    regular_ll
# 86         pf       8    regular_ll
# 87         pf       8    regular_ll
# 88         pf       8    regular_ll
# 89         pf       8    regular_ll
# 90         pf       8    regular_ll
# 91         pf       8    regular_ll
# 92         pf       8    regular_ll
# 93         pf       8    regular_ll
# 94         pf       8    regular_ll
# 95         pf       8    regular_ll
# 96         pf       8    regular_ll
# 97         pf       8    regular_ll
# 98         pf       8    regular_ll
# 99         pf       8    regular_ll
# 100        pf       4    regular_ll
# 101        pf       4    regular_ll
# 102        pf       4    regular_ll
# 103        pf       4    regular_ll
# 104        pf       4    regular_ll
# 105        pf       4    regular_ll
# 106        pf       4    regular_ll
# 107        pf       4    regular_ll
# 108        pf       4    regular_ll
# 109        pf       4    regular_ll
# 110        pf       4    regular_ll
# 111        pf       4    regular_ll
# 112        pf       4    regular_ll
# 113        pf       4    regular_ll
# 114        pf       4    regular_ll
# 115        pf       4    regular_ll
# 116        pf       4    regular_ll
# 117        pf       4    regular_ll
# 118        pf       4    regular_ll
# 119        pf       4    regular_ll
# 120        pf       7    regular_ll
# 121        pf       7    regular_ll
# 122        pf       7    regular_ll
# 123        pf       7    regular_ll
# 124        pf       7    regular_ll
# 125        pf       7    regular_ll
# 126        pf       7    regular_ll
# 127        pf       7    regular_ll
# 128        pf       7    regular_ll
# 129        pf       7    regular_ll
# 130        pf       7    regular_ll
# 131        pf       7    regular_ll
# 132        pf       7    regular_ll
# 133        pf       7    regular_ll
# 134        pf       7    regular_ll
# 135        pf       7    regular_ll
# 136        pf       7    regular_ll
# 137        pf       7    regular_ll
# 138        pf       7    regular_ll
# 139        pf       7    regular_ll
# 140        pf      10    regular_ll
# 141        pf      10    regular_ll
# 142        pf      10    regular_ll
# 143        pf      10    regular_ll
# 144        pf      10    regular_ll
# 145        pf      10    regular_ll
# 146        pf      10    regular_ll
# 147        pf      10    regular_ll
# 148        pf      10    regular_ll
# 149        pf      10    regular_ll
# 150        pf      10    regular_ll
# 151        pf      10    regular_ll
# 152        pf      10    regular_ll
# 153        pf      10    regular_ll
# 154        pf      10    regular_ll
# 155        pf      10    regular_ll
# 156        pf      10    regular_ll
# 157        pf      10    regular_ll
# 158        pf      10    regular_ll
# 159        pf      10    regular_ll
# 160        cf       0    regular_ll
# 161        cf       0    regular_ll
# 162        cf       0    regular_ll
# 163        cf       0    regular_ll
# 164        cf       0    regular_ll
# 165        cf       0    regular_ll
# 166        cf       0    regular_ll
# 167        cf       0    regular_ll
# 168        cf       0    regular_ll
# 169        cf       0    regular_ll
# 170        cf       0    regular_ll
# 171        cf       0    regular_ll
# 172        cf       0    regular_ll
# 173        cf       0    regular_ll
# 174        cf       0    regular_ll
# 175        cf       0    regular_ll
# 176        cf       0    regular_ll
# 177        cf       0    regular_ll
# 178        cf       0    regular_ll
# 179        cf       0    regular_ll
# 180        pf       2    regular_ll
# 181        pf       2    regular_ll
# 182        pf       2    regular_ll
# 183        pf       2    regular_ll
# 184        pf       2    regular_ll
# 185        pf       2    regular_ll
# 186        pf       2    regular_ll
# 187        pf       2    regular_ll
# 188        pf       2    regular_ll
# 189        pf       2    regular_ll
# 190        pf       2    regular_ll
# 191        pf       2    regular_ll
# 192        pf       2    regular_ll
# 193        pf       2    regular_ll
# 194        pf       2    regular_ll
# 195        pf       2    regular_ll
# 196        pf       2    regular_ll
# 197        pf       2    regular_ll
# 198        pf       2    regular_ll
# 199        pf       2    regular_ll
# 200        pf       9    regular_ll
# 201        pf       9    regular_ll
# 202        pf       9    regular_ll
# 203        pf       9    regular_ll
# 204        pf       9    regular_ll
# 205        pf       9    regular_ll
# 206        pf       9    regular_ll
# 207        pf       9    regular_ll
# 208        pf       9    regular_ll
# 209        pf       9    regular_ll
# 210        pf       9    regular_ll
# 211        pf       9    regular_ll
# 212        pf       9    regular_ll
# 213        pf       9    regular_ll
# 214        pf       9    regular_ll
# 215        pf       9    regular_ll
# 216        pf       9    regular_ll
# 217        pf       9    regular_ll
# 218        pf       9    regular_ll
# 219        pf       9    regular_ll

# %%
percentiles100 = list(range(101))
percentiles = [1, 10, 50, 90, 99]
pc = mv.percentile(data=daily_mean, percentiles=percentiles)
pc.ls()
# Out:
#         centre shortName typeOfLevel  level  dataDate  dataTime stepRange  \
# Message
# 0        ecmf      2t       surface     0    20110925      0        162
# 1        ecmf      2t       surface     0    20190925      0        162
# 2        ecmf      2t       surface     0    20120925      0        162
# 3        ecmf      2t       surface     0    20090925      0        162
# 4        ecmf      2t       surface     0    20200925      0        162
#
#         dataType number   gridType
# Message
# 0          pf       5    regular_ll
# 1          pf       5    regular_ll
# 2          pf       5    regular_ll
# 3          pf       5    regular_ll
# 4          pf       5    regular_ll

# %%
data_area = [50,10,40,30]
margins = [2, -2, -2, 2]
view_area = [a + b for a, b in zip(data_area, margins)]

# %%
coastlines = mv.mcoast(map_coastline_land_shade=True,
                       map_coastline_land_shade_colour="RGB(0.85,0.85,0.85)",
                       map_coastline_sea_shade=True,
                       map_coastline_sea_shade_colour="RGB(0.95,0.95,0.95)",)
view = mv.geoview(map_area_definition="corners", area=view_area, coastlines=coastlines)
cont_auto = mv.mcont(legend=True,     
                     contour_automatic_setting = "style_name",
                     contour_style_name        = "sh_mc_t_fM80t60",
                     grib_scaling_of_derived_fields=True)

# %%
mv.plot(view, pc, cont_auto)
# Out:
# Image(value=b'', layout="Layout(visibility='hidden')")
# Label(value='Generating plots....')
# VBox(children=(IntSlider(value=1, description='Frame:', layout=Layout(width='800px'), max=1, min=1), HBox(chil…

# %% [markdown]
# Now finally we can do it for the whole dataset of 7 days forecast.

# %%
clim_dates = sequence.bracket(clim_date,4,strict=False)
for date in clim_dates:
    print(date)
# Out:
# 2024-08-25
# 2024-08-29
# 2024-09-01
# 2024-09-05
# 2024-09-09
# 2024-09-13
# 2024-09-17
# 2024-09-21
# 2024-09-25
